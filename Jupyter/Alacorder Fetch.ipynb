# %%
## SETUP: MUST RUN CELL BEFORE USE. PRESS [SHIFT + RETURN] TO LOAD.
import cython, os, sys, warnings, itables, ipywidgets, IPython.display; import pandas as pd; import pyximport; pyximport.install(); import alac
warnings.filterwarnings('ignore')
sys.tracebacklimit = 0

query_path = ipywidgets.Text(description="Input Path:", layout=ipywidgets.Layout(width='90%'), tooltip="Path to query template spreadsheet (list of names, etc. to search)")
output_dir = ipywidgets.Text(description="Output Path:", layout=ipywidgets.Layout(width='90%'))
cID = ipywidgets.Text(description="Customer ID: ")
uID = ipywidgets.Text(description="User ID: ")
pwd = ipywidgets.Password(description="Password: ")
btn = ipywidgets.Button(description="Login")

def startFetch(*args):
    global clicked, query_path, output_dir, cID, uID, pwd, btn
    if os.path.isdir(output_dir.value) and os.path.isfile(query_path.value) and cID.value != "" and uID.value != "" and pwd.value != "":
        return alac.fetch(query_path.value,output_dir.value,cID=cID.value, uID=uID.value, pwd=pwd.value)
    else:
        display("Ensure all fields are correctly filled, then try again.")
        return None

oQueryTable = ipywidgets.Output()
oQueryTable_hidden = True

def viewQueryTable(*args):
    global oQueryTable
    global oQueryTable_hidden
    if oQueryTable_hidden:
        inputstab = """<style> table {float:left} </style> <table> <thead> <tr> <th>Field</th> <th>Description</th> </tr> </thead> <tbody> <tr> <td><code>NAME</code></td> <td>Last Name First</td> </tr> <tr> <td><code>PARTY_TYPE</code></td> <td>Social Security Number (Optional)</td> </tr> <tr> <td><code>SSN</code></td> <td>Applies to civil cases only (Optional)</td> </tr> <tr> <td><code>DOB</code></td> <td>Date of Birth (M/DD/YYYY)</td> </tr> <tr> <td><code>COUNTY</code></td> <td>Select a county if not statewide</td> </tr> <tr> <td><code>DIVISION</code></td> <td>Select a division if not all divisions.</td> </tr> <tr> <td><code>CASE_YEAR</code></td> <td>Four digit case year to limit results</td> </tr> <tr> <td><code>FILED_BEFORE</code></td> <td>Do not include cases filed after M/DD/YYYY</td> </tr> <tr> <td><code>FILED_AFTER</code></td> <td>Do not include cases filed after M/DD/YYYY</td> </tr> </tbody> </table> """
        oQueryTable_hidden = False
        with oQueryTable:
            display(IPython.display.HTML(inputstab))
    else:
        oQueryTable.clear_output()
        oQueryTable_hidden = True
        pass

alacfetchhead = """<pre><code>    ___    <span class="hljs-symbol">__</span>                          <span class="hljs-symbol">__</span>         
   /   |  / /___  _________  _________/ /<span class="hljs-symbol">__</span>  _____
  / /| | / / <span class="hljs-symbol">__</span> `/ ___/ <span class="hljs-symbol">__</span> \/ ___/ <span class="hljs-symbol">__</span>  / <span class="hljs-symbol">_</span> \/ ___/
 / ___ |/ / /<span class="hljs-symbol">_</span>/ / /<span class="hljs-symbol">__</span>/ /<span class="hljs-symbol">_</span>/ / /  / /<span class="hljs-symbol">_</span>/ /  <span class="hljs-symbol">__</span>/ /    
/<span class="hljs-symbol">_</span>/  |<span class="hljs-symbol">_</span>/<span class="hljs-symbol">_</span>/\<span class="hljs-symbol">__</span>,<span class="hljs-symbol">_</span>/\___/\____/<span class="hljs-symbol">_</span>/   \<span class="hljs-symbol">__</span>,<span class="hljs-symbol">_</span>/\___/<span class="hljs-symbol">_</span>/     

ALACORDER <span class="hljs-built_in">beta</span> <span class="hljs-number">76</span>
</code></pre><h1 id="alacorder-on-jupyter-alac-fetch-">Alacorder on Jupyter: <code>alac.fetch()</code></h1>
<h2 id="collect-case-pdfs-in-bulk-from-alacourt-com-from-a-list-of-names-or-search-parameters-">Collect case PDFs in bulk from Alacourt.com from a list of names or search parameters.</h2>
<p><strong>Use column headers <code>NAME</code>, <code>PARTY_TYPE</code>, <code>SSN</code>, <code>DOB</code>, <code>COUNTY</code>, <code>DIVISION</code>, <code>CASE_YEAR</code>, and/or <code>FILED_BEFORE</code> in an Excel spreadsheet to submit a list of queries for Alacorder to scrape. Each column corresponds to a search field in Party Search. Missing columns and entries will be left empty, i.e. if only the <code>NAME</code>&#39;s and <code>CASE_YEAR</code>&#39;s are relevant to the search, a file with two columns will work.</strong></p>
"""
btn2 = ipywidgets.Button(description="Read more")

def showFetch(*args):
    display(IPython.display.HTML(alacfetchhead))
    display(btn2, oQueryTable)
    btn2.on_click(viewQueryTable)
    display(query_path) 
    display(output_dir) 
    display(cID)
    display(uID)
    display(pwd)
    btn.on_click(startFetch)
    display(btn)

oQueryTable.clear_output()

arc_title = IPython.display.HTML("""<h1 id="case-text-archive">Case Text Archive</h1>
<h2 id="case-text-archives-require-a-fraction-of-the-storage-capacity-and-processing-time-used-to-process-pdf-directories-before-exporting-your-data-to-tables-create-an-archive-with-supported-file-extensions-pkl-xz-json-zip-parquet-and-csv-zip-">Case text archives require a fraction of the storage capacity and processing time used to process PDF directories. Before exporting your data to tables, create an archive with supported file extensions  <code>.pkl.xz</code>, <code>.json(.zip)</code>, <code>.parquet</code> and <code>.csv(.zip)</code>.</h2>
<p><strong>Once archived, use your case text archive as an input for multitable or single table export.</strong></p>
""")
arc_inpath = ipywidgets.Text(description="Input Path", 
                            layout=ipywidgets.Layout(width='90%'), 
                            tooltip="Path to PDF directory (list of names, etc. to search)")

arc_outpath = ipywidgets.Text(description="Output Path", layout=ipywidgets.Layout(width='90%'))
arc_count = ipywidgets.IntText(description="Set max count", layout=ipywidgets.Layout(width='90%'))
arc_overwrite = ipywidgets.Checkbox(description="Allow overwrite")
arc_dedupe = ipywidgets.Checkbox(description="Remove duplicates")
arc_compress = ipywidgets.Checkbox(description="ZIP export (must be .json, .csv)")
arc_btn = ipywidgets.Button(description="Start archiving")

def showArchive():
    global arc_title, arc_inpath, arc_outpath, arc_count, arc_overwrite, arc_dedupe, arc_compress, arc_btn
    display(arc_title)
    display(arc_inpath)
    display(arc_outpath)
    arc_chk = ipywidgets.HBox([arc_overwrite, arc_dedupe, arc_compress])
    display(arc_chk)
    display(arc_btn)
    return None

mtab_title = IPython.display.HTML("""<h1 id="multitable-export">Multitable Export</h1>
<h2 id="multitable-export-processes-case-detail-pdfs-and-case-text-archives-into-data-tables-suitable-for-research-purposes-export-an-excel-spreadsheet-with-detailed-cases-information-cases-fee-sheets-fees-and-charges-information-charges-disposition-filing-">Multitable export processes case detail PDFs and case text archives into data tables suitable for research purposes. Export an Excel spreadsheet with detailed cases information (<code>cases</code>), fee sheets (<code>fees</code>), and charges information (<code>charges</code>, <code>disposition</code>, <code>filing</code>).</h2>
<p><strong><em>Note: It is recommended that you create a case text archive from your target PDF directory before exporting tables. Case text archives can be processed into tables at a much faster rate and require far less storage.</em></strong></p>""")
mtab_inpath = ipywidgets.Text(description="Input Path", 
                        layout=ipywidgets.Layout(width='90%'), 
                        tooltip="Path to input directory or archive")

mtab_outpath = ipywidgets.Text(description="Output Path", layout=ipywidgets.Layout(width='90%'))
mtab_count = ipywidgets.IntText(
    value=0,
    min=0,
    max=10000,
    step=1,
    description='Max count:',
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
mtab_overwrite = ipywidgets.Checkbox(description="Allow overwrite")
mtab_btn = ipywidgets.Button(description="Start export")

mtab_obox = ipywidgets.HBox([mtab_count, mtab_overwrite])
def startMulti(*args):
    global mtab_title, mtab_inpath, mtab_outpath, mtab_count, mtab_overwrite, mtab_btn
    if mtab_inpath.value.strip() != "":
        cf = alac.setpaths(mtab_inpath.value, mtab_outpath.value, overwrite=mtab_overwrite.value, jlog=True)
        return alac.init(cf)
    else:
        return None

def showMulti():
    display(mtab_title)
    display(mtab_obox)
    display(mtab_inpath)
    display(mtab_outpath)
    mtab_btn.on_click(startMulti)
    display(mtab_btn)
    return None


stab_title = IPython.display.HTML("""<h1 id="single-table-export">Single Table Export</h1>
<h2 id="export-charges-including-disposition-only-and-filing-only-cases-or-fees-table-only-single-table-export-enables-file-types-without-support-for-multiple-sheets-this-mode-allows-export-to-csv-json-dta-xls-xlsx-pkl-and-parquet-files-">Export <code>charges</code> (including <code>disposition</code> only and <code>filing</code> only), <code>cases</code>, or <code>fees</code> table only. Single table export enables file types without support for multiple sheets. This mode allows export to <code>.csv</code>, <code>.json</code>, <code>.dta</code>, <code>.xls</code>, <code>.xlsx</code>, <code>.pkl</code>, and <code>.parquet</code> files.</h2>
<p><strong>Once archived, use your case text archive as an input for multitable or single table export.</strong></p>""")
stab_inpath = ipywidgets.Text(description="Input Path", 
                        layout=ipywidgets.Layout(width='90%'), 
                        tooltip="Path to input directory or archive")
stab_table = ipywidgets.ToggleButtons(options=['cases', 'charges', 'disposition', 'filing', 'fees'],description='Table:')

stab_outpath = ipywidgets.Text(description="Output Path", layout=ipywidgets.Layout(width='90%'))
stab_count = ipywidgets.IntText(
    value=0,
    min=0,
    max=10000,
    step=1,
    description='Max count:',
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
stab_overwrite = ipywidgets.Checkbox(description="Allow overwrite")
stab_nobatch = ipywidgets.Checkbox(description="Don't split in batches")
stab_btn = ipywidgets.Button(description="Start export")

stab_obox = ipywidgets.HBox([stab_overwrite, stab_nobatch])

def startSingle(*args):
    global stab_title, stab_inpath, stab_outpath, stab_count, stab_overwrite, stab_btn
    if stab_inpath.value.strip() != "":
        cf = alac.setpaths(stab_inpath.value, stab_outpath.value, table=stab_table.value, overwrite=stab_overwrite.value, no_batch=stab_nobatch.value, jlog=True)
        return alac.init(cf)
    else:
        return None

def showSingle():
    display(stab_title)
    display(stab_obox)
    display(stab_inpath)
    display(stab_outpath)
    display(stab_table)
    stab_btn.on_click(startSingle)
    display(stab_btn)
    return None

# %%
# %pip install --upgrade alacorder
# Out:
# Requirement already satisfied: alacorder in /opt/homebrew/anaconda3/lib/python3.9/site-packages (76.6.1)
# Requirement already satisfied: xarray in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (0.20.1)
# Requirement already satisfied: cython in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (0.29.33)
# Requirement already satisfied: xlrd in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (2.0.1)
# Requirement already satisfied: itables in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (1.4.6)
# Requirement already satisfied: pandas in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (1.5.3)
# Requirement already satisfied: numpy in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (1.23.5)
# Requirement already satisfied: tqdm in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (4.64.1)
# Requirement already satisfied: bottleneck in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (1.3.5)
# Requirement already satisfied: xlwt in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (1.3.0)
# Requirement already satisfied: ipywidgets in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (7.6.5)
# Requirement already satisfied: PyPDF2 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (3.0.1)
# Requirement already satisfied: numexpr in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (2.8.3)
# Requirement already satisfied: ipython in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (8.4.0)
# Requirement already satisfied: selenium in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (4.8.2)
# Requirement already satisfied: click in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (8.0.4)
# Requirement already satisfied: openpyxl in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (3.0.10)
# Requirement already satisfied: jupyter in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (1.0.0)
# Requirement already satisfied: pyarrow in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from alacorder) (11.0.0)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (0.1.6)
# Requirement already satisfied: backcall in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (0.2.0)
# Requirement already satisfied: stack-data in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (3.0.20)
# Requirement already satisfied: pickleshare in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (0.7.5)
# Requirement already satisfied: appnope in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (0.1.2)
# Requirement already satisfied: decorator in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (2.14.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipython->alacorder) (63.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipywidgets->alacorder) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipywidgets->alacorder) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipywidgets->alacorder) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipywidgets->alacorder) (6.15.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipywidgets->alacorder) (0.2.0)
# Requirement already satisfied: qtconsole in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from jupyter->alacorder) (5.4.0)
# Requirement already satisfied: jupyter-console in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from jupyter->alacorder) (6.4.3)
# Requirement already satisfied: nbconvert in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from jupyter->alacorder) (6.4.4)
# Requirement already satisfied: notebook in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from jupyter->alacorder) (6.4.12)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from numexpr->alacorder) (21.3)
# Requirement already satisfied: et_xmlfile in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from openpyxl->alacorder) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from pandas->alacorder) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from pandas->alacorder) (2022.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from PyPDF2->alacorder) (4.3.0)
# Requirement already satisfied: trio~=0.17 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from selenium->alacorder) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from selenium->alacorder) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from selenium->alacorder) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from selenium->alacorder) (2022.12.7)
# Requirement already satisfied: debugpy>=1.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->alacorder) (1.5.1)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->alacorder) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->alacorder) (23.2.0)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->alacorder) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->alacorder) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->alacorder) (7.3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->alacorder) (0.8.3)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->alacorder) (2.16.2)
# Requirement already satisfied: jupyter_core in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->alacorder) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->alacorder) (4.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->alacorder) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->alacorder) (0.2.5)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->alacorder) (1.16.0)
# Requirement already satisfied: sortedcontainers in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->alacorder) (2.4.0)
# Requirement already satisfied: idna in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->alacorder) (3.3)
# Requirement already satisfied: async-generator>=1.9 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->alacorder) (1.10)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->alacorder) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->alacorder) (21.4.0)
# Requirement already satisfied: outcome in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->alacorder) (1.2.0)
# Requirement already satisfied: sniffio in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium->alacorder) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium->alacorder) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from urllib3[socks]~=1.26->selenium->alacorder) (1.7.1)
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->alacorder) (0.13.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->alacorder) (2.11.3)
# Requirement already satisfied: prometheus-client in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->alacorder) (0.14.1)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->alacorder) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from notebook->jupyter->alacorder) (1.8.0)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (4.11.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (0.8.4)
# Requirement already satisfied: testpath in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (1.5.0)
# Requirement already satisfied: bleach in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from nbconvert->jupyter->alacorder) (0.5.13)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from packaging->numexpr->alacorder) (3.0.9)
# Requirement already satisfied: qtpy>=2.0.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from qtconsole->jupyter->alacorder) (2.2.0)
# Requirement already satisfied: asttokens in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->alacorder) (2.0.5)
# Requirement already satisfied: executing in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->alacorder) (0.8.3)
# Requirement already satisfied: pure-eval in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->alacorder) (0.2.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from jinja2->notebook->jupyter->alacorder) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->alacorder) (0.18.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->alacorder) (0.14.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->alacorder) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter->alacorder) (2.3.1)
# Requirement already satisfied: webencodings in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->jupyter->alacorder) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->alacorder) (1.15.1)
# Requirement already satisfied: pycparser in /opt/homebrew/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->alacorder) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
showMulti()
# Out:
# <h1 id="multitable-export">Multitable Export</h1>
# <h2 id="multitable-export-processes-case-detail-pdfs-and-case-text-archives-into-data-tables-suitable-for-research-purposes-export-an-excel-spreadsheet-with-detailed-cases-information-cases-fee-sheets-fees-and-charges-information-charges-disposition-filing-">Multitable export processes case detail PDFs and case text archives into data tables suitable for research purposes. Export an Excel spreadsheet with detailed cases information (<code>cases</code>), fee sheets (<code>fees</code>), and charges information (<code>charges</code>, <code>disposition</code>, <code>filing</code>).</h2>
# <p><strong><em>Note: It is recommended that you create a case text archive from your target PDF directory before exporting tables. Case text archives can be processed into tables at a much faster rate and require far less storage.</em></strong></p>
# HBox(children=(IntText(value=0, description='Max count:'), Checkbox(value=False, description='Allow overwrite'…
# Text(value='', description='Input Path', layout=Layout(width='90%'))
# Text(value='', description='Output Path', layout=Layout(width='90%'))
# Button(description='Start export', style=ButtonStyle())
# Found 14064 cases in input.
#
# * Successfully configured!
# INPUT: /Users/samuelrobson/Desktop/NewTut.pkl.xz
# TABLE: /Users/samuelrobson/Desktop/abcdefghijklmnopqrs.xlsx
# Case Info:   0%|          | 0/14064 [00:00<?, ?it/s]
# Charges:   0%|          | 0/14064 [00:00<?, ?it/s]
# Fee Sheets:   0%|          | 0/14064 [00:00<?, ?it/s]
#                  CaseNumber                        Name             Alias  \
# 0      01-DC-2005-010388.00        CATLIN DETRA LYNIECE
# 1      31-TR-2014-004104.00    MCALISTER JUSTINE ALYSSA
# 2      27-DC-2012-000593.00  BLOUNT ELIZABETH D #315672
# 3      01-CC-1999-002261.70         MILLER MARY ANNETTE    MILLER ANNETTE
# 4      01-CC-2005-004711.00        BOYD GLADYS MICHELLE  JOHNSON MICHELLE
# ...                     ...                         ...               ...
# 14059  47-TR-2007-012252.00            BOLE PORSHA DAWN
# 14060  52-CC-2013-000934.00          BORDEN ASHLEY JEAN
# 14061  58-CC-2017-000855.00     WALDROP ALEXANDRIA JADE
# 14062  43-TR-1994-000054.00          WATSON TONIA MARIE
# 14063  44-DC-2017-001099.00       JARRETT CHRISTINA LEE
#
#               DOB Race Sex                                       Address  \
# 0      09/02/1984    B   F      840 W J PRATT ST BIRMINGHAM,  35224-0000
# 1      05/17/1994    W   F       1312 MERRYHILL AVE GADSDEN,  35903-0000
# 2      10/31/1963    B   F   JULIA TUTWILER PRISON WETUMPKA,  36092-0000
# 3      08/14/1966    W   F            15950 CO RD 44 LINDEN,  35205-0000
# 4      12/15/1966    B   F   1833 32ND ST ENSLEY BIRMINGHAM,  35208-0000
# ...           ...  ...  ..                                           ...
# 14059  11/06/1987    W   F        101 OLDWOOD RD HUNTSVILLE,  35811-0000
# 14060  08/27/1989    W   F  1498 HIGHWAY 67 S LOT Q DECATUR,  35603-0000
# 14061  01/14/1994    W   F   12984 BUCKSVILLE DRIVE MCCALLA,  35111-0000
# 14062  10/18/1974    B   F   13 CANDLEWOOD APTS PHENIX CITY,  36867-0000
# 14063  02/05/1991    W   F        23791 NORMAN LANE ELKMONT,  35620-0000
#
#               Phone                                        Convictions  \
# 0
# 1                    001 T636 06/19/2016 GUILTY PLEA TRAFFIC TRAFFI...
# 2
# 3
# 4       205780692.0  001 ROB3 02/06/2006 GUILTY PLEA PERSONAL FELON...
# ...             ...                                                ...
# 14059                001 T075 11/16/2007 GUILTY PLEA TRAFFIC TRAFFI...
# 14060
# 14061   205370720.0
# 14062  2052911564.0  001 T001 03/22/1994 GUILTY PLEA TRAFFIC MISDEM...
# 14063
#
#                                       Dispositioncharges  ...  \
# 0                                                         ...
# 1      001 T636 06/19/2016 GUILTY PLEA TRAFFIC TRAFFI...  ...
# 2                                                         ...
# 3                                                         ...
# 4      001 ROB3 02/06/2006 GUILTY PLEA PERSONAL FELON...  ...
# ...                                                  ...  ...
# 14059  001 T075 11/16/2007 GUILTY PLEA TRAFFIC TRAFFI...  ...
# 14060  001 MCS1 08/20/2013 DISMISSED DRUG FELONY 13A-...  ...
# 14061                                                     ...
# 14062  001 T001 03/22/1994 GUILTY PLEA TRAFFIC MISDEM...  ...
# 14063                                                     ...
#
#       CERVConvictionCount PardonConvictionCount PermanentConvictionCount  \
# 0                       0                     0                        0
# 1                       0                     0                        0
# 2                       0                     0                        0
# 3                       0                     0                        0
# 4                       1                     0                        0
# ...                   ...                   ...                      ...
# 14059                   0                     0                        0
# 14060                   0                     0                        0
# 14061                   0                     0                        0
# 14062                   0                     0                        0
# 14063                   0                     0                        0
#
#       ChargeCodes  ConvictionCodes  TotalAmtDue  TotalBalance  \
# 0
# 1            T636             T636
# 2
# 3
# 4            ROB3             ROB3        502.0         502.0
# ...           ...              ...          ...           ...
# 14059        T075             T075        155.0           0.0
# 14060        MCS1
# 14061                                    1005.0         505.0
# 14062        T001             T001         89.0           0.0
# 14063
#
#        PaymentToRestore                                   FeeCodesOwed  \
# 0
# 1                                                  ST00 TADM SWSF ST10
# 2
# 3
# 4                 502.0       SF00 SF80 SF30 SF50 SF71 SF72 SF73 SO75
# ...                 ...                                            ...
# 14059               0.0                                     ST00 ST10
# 14060
# 14061             505.0  CADM SF00 SFW0 SF70 SF71 SF72 SO75 JBKF LOAF
# 14062               0.0                                     ST00 ST10
# 14063
#
#                                             FeeCodes
# 0
# 1                               ST00 TADM SWSF ST10
# 2
# 3
# 4           SF00 SF80 SF30 SF50 SF71 SF72 SF73 SO75
# ...                                              ...
# 14059                                     ST00 ST10
# 14060
# 14061  CADM SF00 SFW0 SF70 SF71 SF72 SO75 JBKF LOAF
# 14062                                     ST00 ST10
# 14063
#
# [14064 rows x 29 columns]
#                  CaseNumber FeeStatus AdminFee  Total  Code Payor   AmtDue  \
# 0      31-TR-2014-004104.00    ACTIVE        N         ST00  D001     0.00
# 1      31-TR-2014-004104.00    ACTIVE        N         TADM  D001     0.00
# 2      31-TR-2014-004104.00    ACTIVE        N         SWSF  D001     0.00
# 3      31-TR-2014-004104.00    ACTIVE        N         ST10  D001     0.00
# 4      31-TR-2014-004104.00                     TOTAL
# ...                     ...       ...      ...    ...   ...   ...      ...
# 46070  58-CC-2017-000855.00    ACTIVE        N         LOAF  D001    20.00
# 46071  58-CC-2017-000855.00                     TOTAL              1005.00
# 46072  43-TR-1994-000054.00    ACTIVE        N         ST00          69.00
# 46073  43-TR-1994-000054.00    ACTIVE        N         ST10          20.00
# 46074  43-TR-1994-000054.00                     TOTAL                89.00
#
#       AmtPaid Balance AmtHold
# 0        0.00    0.00    0.00
# 1        0.00    0.00    0.00
# 2        0.00    0.00    0.00
# 3        0.00    0.00    0.00
# 4
# ...       ...     ...     ...
# 46070    0.00   20.00    0.00
# 46071  500.00  505.00    0.00
# 46072   69.00    0.00    0.00
# 46073   20.00    0.00    0.00
# 46074   89.00    0.00    0.00
#
# [46075 rows x 10 columns]
#                                                  Charges  \
# 0      001 T636 NO TINT COMPL LABEL 032-05C-006 TRAFF...
# 1      001 T636 06/19/2016 GUILTY PLEA TRAFFIC TRAFFI...
# 2            001 MURD MURDER 13A-006-002 FELONY PERSONAL
# 3      001 UDCS UNLAW DISTRIB/FURN CONT SUBST 13A-012...
# 4       001 ROB3 ROBBERY 3RD 13A-008-043 FELONY PERSONAL
# ...                                                  ...
# 18680  001 MCS1 08/20/2013 DISMISSED DRUG FELONY 13A-...
# 18681  001 TET3 THEFT OF PROPERTY 3RD DEGREE 13A-008-...
# 18682  001 T001 SPEED LESS 25MPH 032-05A-171 MISDEMEA...
# 18683  001 T001 03/22/1994 GUILTY PLEA TRAFFIC MISDEM...
# 18684  001 FLEE ATTEMPT TO ELUDE 13A-010-052 MISDEMEA...
#
#                  CaseNumber  Num  Code  Felony  Conviction   CERV  Pardon  \
# 0      31-TR-2014-004104.00  001  T636   False       False  False   False
# 1      31-TR-2014-004104.00  001  T636   False        True  False   False
# 2      27-DC-2012-000593.00  001  MURD    True       False  False    True
# 3      01-CC-1999-002261.70  001  UDCS    True       False  False   False
# 4      01-CC-2005-004711.00  001  ROB3    True       False   True   False
# ...                     ...  ...   ...     ...         ...    ...     ...
# 18680  52-CC-2013-000934.00  001  MCS1    True       False  False   False
# 18681  58-CC-2017-000855.00  001  TET3    True       False  False   False
# 18682  43-TR-1994-000054.00  001  T001   False       False  False   False
# 18683  43-TR-1994-000054.00  001  T001   False        True  False   False
# 18684  44-DC-2017-001099.00  001  FLEE   False       False  False   False
#
#        Permanent  Disposition CourtActionDate  CourtAction           Cite  \
# 0          False        False                                 032-05C-006
# 1          False         True      06/19/2016  GUILTY PLEA    032-05C-006
# 2          False        False                                 13A-006-002
# 3          False        False                                 13A-012-211
# 4          False        False                                 13A-008-043
# ...          ...          ...             ...          ...            ...
# 18680      False         True      08/20/2013    DISMISSED    13A-012-218
# 18681      False        False                               13A-008-004.1
# 18682      False        False                                 032-05A-171
# 18683      False         True      03/22/1994  GUILTY PLEA    032-05A-171
# 18684      False        False                                 13A-010-052
#
#       TypeDescription    Category                    Description
# 0             TRAFFIC     TRAFFIC            NO TINT COMPL LABEL
# 1             TRAFFIC     TRAFFIC            NO TINT COMPL LABEL
# 2              FELONY    PERSONAL                         MURDER
# 3              FELONY        DRUG  UNLAW DISTRIB/FURN CONT SUBST
# 4              FELONY    PERSONAL                    ROBBERY 3RD
# ...               ...         ...                            ...
# 18680          FELONY        DRUG        UNLAW MANF CTN SUBS 1ST
# 18681          FELONY    PROPERTY   THEFT OF PROPERTY 3RD DEGREE
# 18682     MISDEMEANOR     TRAFFIC               SPEED LESS 25MPH
# 18683         TRAFFIC     TRAFFIC               SPEED LESS 25MPH
# 18684     MISDEMEANOR  GOVERNMENT  MISDEMEANOR GOVERNMENT PUBLIC
#
# [18685 rows x 16 columns]
# * Task completed in 244 seconds.
# [                 CaseNumber                        Name             Alias  \
#  0      01-DC-2005-010388.00        CATLIN DETRA LYNIECE
#  1      31-TR-2014-004104.00    MCALISTER JUSTINE ALYSSA
#  2      27-DC-2012-000593.00  BLOUNT ELIZABETH D #315672
#  3      01-CC-1999-002261.70         MILLER MARY ANNETTE    MILLER ANNETTE
#  4      01-CC-2005-004711.00        BOYD GLADYS MICHELLE  JOHNSON MICHELLE
#  ...                     ...                         ...               ...
#  14059  47-TR-2007-012252.00            BOLE PORSHA DAWN
#  14060  52-CC-2013-000934.00          BORDEN ASHLEY JEAN
#  14061  58-CC-2017-000855.00     WALDROP ALEXANDRIA JADE
#  14062  43-TR-1994-000054.00          WATSON TONIA MARIE
#  14063  44-DC-2017-001099.00       JARRETT CHRISTINA LEE
#
#                DOB Race Sex                                       Address  \
#  0      09/02/1984    B   F      840 W J PRATT ST BIRMINGHAM,  35224-0000
#  1      05/17/1994    W   F       1312 MERRYHILL AVE GADSDEN,  35903-0000
#  2      10/31/1963    B   F   JULIA TUTWILER PRISON WETUMPKA,  36092-0000
#  3      08/14/1966    W   F            15950 CO RD 44 LINDEN,  35205-0000
#  4      12/15/1966    B   F   1833 32ND ST ENSLEY BIRMINGHAM,  35208-0000
#  ...           ...  ...  ..                                           ...
#  14059  11/06/1987    W   F        101 OLDWOOD RD HUNTSVILLE,  35811-0000
#  14060  08/27/1989    W   F  1498 HIGHWAY 67 S LOT Q DECATUR,  35603-0000
#  14061  01/14/1994    W   F   12984 BUCKSVILLE DRIVE MCCALLA,  35111-0000
#  14062  10/18/1974    B   F   13 CANDLEWOOD APTS PHENIX CITY,  36867-0000
#  14063  02/05/1991    W   F        23791 NORMAN LANE ELKMONT,  35620-0000
#
#                Phone                                        Convictions  \
#  0
#  1                    001 T636 06/19/2016 GUILTY PLEA TRAFFIC TRAFFI...
#  2
#  3
#  4       205780692.0  001 ROB3 02/06/2006 GUILTY PLEA PERSONAL FELON...
#  ...             ...                                                ...
#  14059                001 T075 11/16/2007 GUILTY PLEA TRAFFIC TRAFFI...
#  14060
#  14061   205370720.0
#  14062  2052911564.0  001 T001 03/22/1994 GUILTY PLEA TRAFFIC MISDEM...
#  14063
#
#                                        Dispositioncharges  ...  \
#  0                                                         ...
#  1      001 T636 06/19/2016 GUILTY PLEA TRAFFIC TRAFFI...  ...
#  2                                                         ...
#  3                                                         ...
#  4      001 ROB3 02/06/2006 GUILTY PLEA PERSONAL FELON...  ...
#  ...                                                  ...  ...
#  14059  001 T075 11/16/2007 GUILTY PLEA TRAFFIC TRAFFI...  ...
#  14060  001 MCS1 08/20/2013 DISMISSED DRUG FELONY 13A-...  ...
#  14061                                                     ...
#  14062  001 T001 03/22/1994 GUILTY PLEA TRAFFIC MISDEM...  ...
#  14063                                                     ...
#
#        CERVConvictionCount PardonConvictionCount PermanentConvictionCount  \
#  0                       0                     0                        0
#  1                       0                     0                        0
#  2                       0                     0                        0
#  3                       0                     0                        0
#  4                       1                     0                        0
#  ...                   ...                   ...                      ...
#  14059                   0                     0                        0
#  14060                   0                     0                        0
#  14061                   0                     0                        0
#  14062                   0                     0                        0
#  14063                   0                     0                        0
#
#        ChargeCodes  ConvictionCodes  TotalAmtDue  TotalBalance  \
#  0
#  1            T636             T636
#  2
#  3
#  4            ROB3             ROB3        502.0         502.0
#  ...           ...              ...          ...           ...
#  14059        T075             T075        155.0           0.0
#  14060        MCS1
#  14061                                    1005.0         505.0
#  14062        T001             T001         89.0           0.0
#  14063
#
#         PaymentToRestore                                   FeeCodesOwed  \
#  0
#  1                                                  ST00 TADM SWSF ST10
#  2
#  3
#  4                 502.0       SF00 SF80 SF30 SF50 SF71 SF72 SF73 SO75
#  ...                 ...                                            ...
#  14059               0.0                                     ST00 ST10
#  14060
#  14061             505.0  CADM SF00 SFW0 SF70 SF71 SF72 SO75 JBKF LOAF
#  14062               0.0                                     ST00 ST10
#  14063
#
#                                              FeeCodes
#  0
#  1                               ST00 TADM SWSF ST10
#  2
#  3
#  4           SF00 SF80 SF30 SF50 SF71 SF72 SF73 SO75
#  ...                                              ...
#  14059                                     ST00 ST10
#  14060
#  14061  CADM SF00 SFW0 SF70 SF71 SF72 SO75 JBKF LOAF
#  14062                                     ST00 ST10
#  14063
#
#  [14064 rows x 29 columns],
#                   CaseNumber FeeStatus AdminFee  Total  Code Payor   AmtDue  \
#  0      31-TR-2014-004104.00    ACTIVE        N         ST00  D001     0.00
#  1      31-TR-2014-004104.00    ACTIVE        N         TADM  D001     0.00
#  2      31-TR-2014-004104.00    ACTIVE        N         SWSF  D001     0.00
#  3      31-TR-2014-004104.00    ACTIVE        N         ST10  D001     0.00
#  4      31-TR-2014-004104.00                     TOTAL
#  ...                     ...       ...      ...    ...   ...   ...      ...
#  46070  58-CC-2017-000855.00    ACTIVE        N         LOAF  D001    20.00
#  46071  58-CC-2017-000855.00                     TOTAL              1005.00
#  46072  43-TR-1994-000054.00    ACTIVE        N         ST00          69.00
#  46073  43-TR-1994-000054.00    ACTIVE        N         ST10          20.00
#  46074  43-TR-1994-000054.00                     TOTAL                89.00
#
#        AmtPaid Balance AmtHold
#  0        0.00    0.00    0.00
#  1        0.00    0.00    0.00
#  2        0.00    0.00    0.00
#  3        0.00    0.00    0.00
#  4
#  ...       ...     ...     ...
#  46070    0.00   20.00    0.00
#  46071  500.00  505.00    0.00
#  46072   69.00    0.00    0.00
#  46073   20.00    0.00    0.00
#  46074   89.00    0.00    0.00
#
#  [46075 rows x 10 columns],
#                                                   Charges  \
#  0      001 T636 NO TINT COMPL LABEL 032-05C-006 TRAFF...
#  1      001 T636 06/19/2016 GUILTY PLEA TRAFFIC TRAFFI...
#  2            001 MURD MURDER 13A-006-002 FELONY PERSONAL
#  3      001 UDCS UNLAW DISTRIB/FURN CONT SUBST 13A-012...
#  4       001 ROB3 ROBBERY 3RD 13A-008-043 FELONY PERSONAL
#  ...                                                  ...
#  18680  001 MCS1 08/20/2013 DISMISSED DRUG FELONY 13A-...
#  18681  001 TET3 THEFT OF PROPERTY 3RD DEGREE 13A-008-...
#  18682  001 T001 SPEED LESS 25MPH 032-05A-171 MISDEMEA...
#  18683  001 T001 03/22/1994 GUILTY PLEA TRAFFIC MISDEM...
#  18684  001 FLEE ATTEMPT TO ELUDE 13A-010-052 MISDEMEA...
#
#                   CaseNumber  Num  Code  Felony  Conviction   CERV  Pardon  \
#  0      31-TR-2014-004104.00  001  T636   False       False  False   False
#  1      31-TR-2014-004104.00  001  T636   False        True  False   False
#  2      27-DC-2012-000593.00  001  MURD    True       False  False    True
#  3      01-CC-1999-002261.70  001  UDCS    True       False  False   False
#  4      01-CC-2005-004711.00  001  ROB3    True       False   True   False
#  ...                     ...  ...   ...     ...         ...    ...     ...
#  18680  52-CC-2013-000934.00  001  MCS1    True       False  False   False
#  18681  58-CC-2017-000855.00  001  TET3    True       False  False   False
#  18682  43-TR-1994-000054.00  001  T001   False       False  False   False
#  18683  43-TR-1994-000054.00  001  T001   False        True  False   False
#  18684  44-DC-2017-001099.00  001  FLEE   False       False  False   False
#
#         Permanent  Disposition CourtActionDate  CourtAction           Cite  \
#  0          False        False                                 032-05C-006
#  1          False         True      06/19/2016  GUILTY PLEA    032-05C-006
#  2          False        False                                 13A-006-002
#  3          False        False                                 13A-012-211
#  4          False        False                                 13A-008-043
#  ...          ...          ...             ...          ...            ...
#  18680      False         True      08/20/2013    DISMISSED    13A-012-218
#  18681      False        False                               13A-008-004.1
#  18682      False        False                                 032-05A-171
#  18683      False         True      03/22/1994  GUILTY PLEA    032-05A-171
#  18684      False        False                                 13A-010-052
#
#        TypeDescription    Category                    Description
#  0             TRAFFIC     TRAFFIC            NO TINT COMPL LABEL
#  1             TRAFFIC     TRAFFIC            NO TINT COMPL LABEL
#  2              FELONY    PERSONAL                         MURDER
#  3              FELONY        DRUG  UNLAW DISTRIB/FURN CONT SUBST
#  4              FELONY    PERSONAL                    ROBBERY 3RD
#  ...               ...         ...                            ...
#  18680          FELONY        DRUG        UNLAW MANF CTN SUBS 1ST
#  18681          FELONY    PROPERTY   THEFT OF PROPERTY 3RD DEGREE
#  18682     MISDEMEANOR     TRAFFIC               SPEED LESS 25MPH
#  18683         TRAFFIC     TRAFFIC               SPEED LESS 25MPH
#  18684     MISDEMEANOR  GOVERNMENT  MISDEMEANOR GOVERNMENT PUBLIC
#
#  [18685 rows x 16 columns]]

# %%
showArchive()
# Out:
# <h1 id="case-text-archive">Case Text Archive</h1>
# <h2 id="case-text-archives-require-a-fraction-of-the-storage-capacity-and-processing-time-used-to-process-pdf-directories-before-exporting-your-data-to-tables-create-an-archive-with-supported-file-extensions-pkl-xz-json-zip-parquet-and-csv-zip-">Case text archives require a fraction of the storage capacity and processing time used to process PDF directories. Before exporting your data to tables, create an archive with supported file extensions  <code>.pkl.xz</code>, <code>.json(.zip)</code>, <code>.parquet</code> and <code>.csv(.zip)</code>.</h2>
# <p><strong>Once archived, use your case text archive as an input for multitable or single table export.</strong></p>
# Text(value='/Users/samuelrobson/Desktop/NewTut.pkl.xz', description='Input Path', layout=Layout(width='90%'))
# Text(value='/Users/samuelrobson/Desktop/switchforamat.json', description='Output Path', layout=Layout(width='9…
# HBox(children=(Checkbox(value=False, description='Allow overwrite'), Checkbox(value=True, description='Remove …
# Button(description='Start archiving', style=ButtonStyle())

# %%
showSingle()
# Out:
# <h1 id="single-table-export">Single Table Export</h1>
# <h2 id="export-charges-including-disposition-only-and-filing-only-cases-or-fees-table-only-single-table-export-enables-file-types-without-support-for-multiple-sheets-this-mode-allows-export-to-csv-json-dta-xls-xlsx-pkl-and-parquet-files-">Export <code>charges</code> (including <code>disposition</code> only and <code>filing</code> only), <code>cases</code>, or <code>fees</code> table only. Single table export enables file types without support for multiple sheets. This mode allows export to <code>.csv</code>, <code>.json</code>, <code>.dta</code>, <code>.xls</code>, <code>.xlsx</code>, <code>.pkl</code>, and <code>.parquet</code> files.</h2>
# <p><strong>Once archived, use your case text archive as an input for multitable or single table export.</strong></p>
# HBox(children=(Checkbox(value=False, description='Allow overwrite'), Checkbox(value=False, description="Don't …
# Text(value='', description='Input Path', layout=Layout(width='90%'))
# Text(value='', description='Output Path', layout=Layout(width='90%'))
# ToggleButtons(description='Table:', options=('cases', 'charges', 'disposition', 'filing', 'fees'), value='case…
# Button(description='Start export', style=ButtonStyle())
